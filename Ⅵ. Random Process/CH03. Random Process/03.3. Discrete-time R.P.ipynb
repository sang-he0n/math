# %% [markdown]
# # CH03.3. **Discrete-time Random Process**

# %% [markdown]
# > ## **(White Noise)**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(Simple Random Walk)**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(Finite-state Markov chain)**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(AR process)**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(ARMA)**
