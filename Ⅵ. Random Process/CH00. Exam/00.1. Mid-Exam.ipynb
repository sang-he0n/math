# %% [markdown]
# # CH00.1. **Mid-term Examination(Quiz)**

# %% [markdown]
# > ## **Q1. Independence**

# %% [markdown]
# #### $ \text{Let } X_{1} \text{ and } X_{2} \text{ be two independent random variables taking values in } \{ 0, 1 \} $.
# #### $ \text{where } P(X_{i} = 0) = P(X_{i} = 1) = 0.5 \text{ for } i = 1, 2 $.
# #### $ \text{and Let } X_{3} = X_{1} \oplus{} X_{2}, \;\; \text{ i.e, the Boolean exclusive-OR (XOR) of } X_{1} \text{ and } X_{2} $.

# %% [markdown]
# #### **(1)** $ \text{Are } X_{1} \text{ and } X_{2} \text{ and } X_{3} \text{ mutually independent? Justify your answer.} $

# %% [markdown]
# #### **(2)** $ \text{Are } X_{1} \text{ and } X_{2} \text{ and } X_{3} \text{ pairwise independent? Justify your answer.} $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Q2. Discrete RV**

# %% [markdown]
# #### $ \text{Bob has two coins in his pocket: one is a fair coin with a head and a tail, the other is a special coin with two heads.} $
# #### $ \text{Bob picks out a coin randomly, tosses it and observes if he gets a head or a tail.} $
# #### $ \text{After that, he puts the coin back into the pocket and repeats the procedure once more.} $

# %% [markdown]
# #### **(1)** $ \text{Specify the sample space } \Omega{}. $

# %% [markdown]
# #### **(2)** $ \text{Specify the event space } \mathcal{F} $.

# %% [markdown]
# #### **(3)** $ \text{Specify the probability measure } P \text{ assigned to each event in } \mathcal{F} $.

# %% [markdown]
# #### **(4)** $ \text{What is the probability that a head was obtained in the first toss given that the second toss is a tail?} $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Q3. Continuous RV**

# %% [markdown]
# #### $ \text{Let } X \text{ and } Y \text{ be the coordinates of a point selected uniformly at random from the triangle} $
# #### $ \text{with vertices } (0,0), (0,1), (1,0) \text{ in } \mathbb{R}^{2}. $
# #### <p align="center"> <img src="../img/00.2. Mid-Exam (1).png" width="30%" height="30%"></img> </p>

# %% [markdown]
# #### **(1)** $ \text{Find the pdf of } X. $

# %% [markdown]
# #### **(2)** $ \text{Are } X \text{ and } Y \text{ independent? Justify your answer.} $

# %% [markdown]
# #### **(3)** $ \text{Find } \mathbb{E}[X^2 | Y = y] \text{ for } y \in{} (0,1) $.

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Q4. Composite Continuous RV**

# %% [markdown]
# #### $ \text{Suppose } (U, V) \text{ has joint pdf}, $
# #### $$ f_{UV}(u,v) = \begin{cases} 8u^{2}v^{2}, & \text{if } 0 \leq{} u \leq{} 1 \;\; \text{and} \;\; 0 \leq{} v \leq{} 1 \\ 0, & \text{otherwise} \end{cases} $$
# #### $ \text{and let } X = 2U \text{ and } Y = UV. $

# %% [markdown]
# #### **(1)** $ \text{Find the joint pdf of } X \text{ and } Y\text{, being sure to specify where the joint pdf is zero.} $

# %% [markdown]
# #### **(2)** $ \text{Find the conditional pdf } f_{Y \;| \; X}(y \; | \; x) \text{ of } Y \text{ given } X. $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Q5. Characteristic Function**

# %% [markdown]
# #### $ \text{ As we saw in class, the joint characteristic function of random variables } X_{1}, X_{2}, \cdots{}, X_{n} \text{ is defined by} $
# #### $$ \Phi_{X_{1},X_{2},\dots,X_{n}}(u_{1},u_{2},\dots,u_{n}) = \mathbb{E}\!\left[{} \exp{}\Bigg({} j \sum_{k=1}^{n} X_{k}u_{k} \Bigg){} \right]{} \;\; \text{ where } j = \sqrt{-1}. $$
# #### $ \text{Now suppose the joint characteristic function of three random variables } X_{1}, X_{2}, X_{3} \text{ satisfies the equation} : $
# #### $$ \hspace{0.15cm} \Phi_{X_{1},X_{2},X_{3}}(u_{1},u_{2},u_{3}) = \exp{}\Bigg( j \sum_{k=1}^{3} ku_{k} \;-\; \sum_{k=1}^{3} k^{2}u_{k}^{2} \Bigg){} $$

# %% [markdown]
# #### **(1)** $ \text{Find the characteristic function of } X_{2}. $

# %% [markdown]
# #### **(2)** $ \text{Evaluate } \mathbb{E}[X_{2}] \text{ and } \mathrm{Var}(X_{2}). $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Q6. Joint PDF**

# %% [markdown]
# #### $ \text{Suppose } X \text{ and } Y \text{ are jointly continuous-type random variables with joint pdf} : $
# #### $$ f_{X,Y}(u,v) = \begin{cases} \alpha (u + v^2), & 0 \leq{} u \leq{} 1, \;\; 0 \leq{} v \leq{} 2u \\ 0, & \text{else.} \end{cases} $$
# #### $ \text{where } \alpha{} \text{ is a positive real that you will find}. $

# %% [markdown]
# #### **(1)** $ \text{Determine whether } X \text{ and } Y \text{ are independent. Justify your answer.} $

# %% [markdown]
# #### **(2)** $ \text{Find the marginal pdf} f_{X}(u). $
# #### $ \text{(You can express your answer using } \alpha{}. \text{ Specify the pdf over the entire line, including where it is zero.)} $

# %% [markdown]
# #### **(3)** $ \text{Compute the value of } \alpha{}. $

# %% [markdown]
# #### **(4)** $ \text{For what values of } u \text{ is the conditional pdf } f_{Y|X}(v|u) \text{ well defined for all } v ? $

# %% [markdown]
# #### **(5)** $ \text{Find } P(X < Y). $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Q7. Expectation and Correlation**

# %% [markdown]
# #### $ \text{Given a random variable } X \text{ and } W, V \text{ (considered to be noise) are added to } X \text{ to form the observations} $
# #### $$ Y = X + V $$
# #### $$ Z = X + W $$
# #### $ \text{Both } W \text{ and } V \text{ are assumed to be independent of } X . $
# #### $ \text{Suppose that all variables have mean } 0, \text{ that } X \text{ has variance } \sigma{}_{X}^{2}, \text{the random variables } W \text{ and } V \text{ have equal}$
# #### $ \text{variance } \sigma{}^2.  \text{Finally, suppose that } W \text{ and } V \text{ are such that} $
# #### $$ \mathbb{E}[VW] = \rho{} \sigma{}^{2} $$
# #### $ \text{where } \rho{} \in [-1,1] \text{ is called the correlation coefficient.} $

# %% [markdown]
# #### **(1)** $ \text{Find } \mathbb{E}[YZ] $

# %% [markdown]
# #### **(2)** $ \text{Suppose that we cannot observe } X, \text{but wish to estimate it based on the observations } Y \text{ and/or } Z. $
# #### $ \text{Two possible estimates are } \hat{X}_{1} = Y \text{ and } \hat{X}_{2} = \dfrac{Y + Z}{2}. $
# #### $ \text{In other words, the estimate } \hat{X}_{1} \text{ only makes use of one observation, while } \hat{X}_{2} \text{ looks at both.} $
# #### $ \text{For what values of } \rho{} \text{ is } \hat{X}_2 \text{ the better estimate of the two in the sense that } \mathbb{E}\big[(X - \hat{X}_2)^2\big] < \mathbb{E}\big[(X - \hat{X}_1)^2\big]? $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Q8. Gaussian Distribution**

# %% [markdown]
# #### **(1)** $ \text{Assume that } X \text{ and } Y \text{ are independent Gaussian random variables with mean } 0 \text{ and variance } 1. $
# #### $ \text{Prove that } \mathbb{E}[X + Y] = 0, \;\; \mathbb{E}[(X + Y)^2] = 2 $

# %% [markdown]
# #### **(2)** $ \text{Assume that } X \sim{} \mathcal{N}(\mu{}_{X}, \sigma{}_{X}^{2}) \text{ and } Y \sim{} \mathcal{N}(\mu{}_Y, \sigma_Y^2) \text{ are independent.} $
# #### $ \text{Show that } X + Y \sim{} \mathcal{N}(\mu{}_X + \mu{}_Y, \; \sigma_X^2 + \sigma_Y^2) $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **Q9. Probability Space**

# %% [markdown]
# #### $ \text{Let } (\Omega{}, \mathcal{F}, P) \text{ be the probability space. Let } L^{2}(\Omega{}) = \{ X : \Omega{} \to{} \mathbb{R} \mid{} \mathbb{E}[|X|^{2}] < \infty{} \} $

# %% [markdown]
# #### **(1)** $ \text{Show that } L^{2}(\Omega{}) \text{ is a vector space.} $

# %% [markdown]
# #### **(2)** $ \text{For } X \in{} L^{2}(\Omega{}), \text{ define} |X| := \big( \mathbb{E}[|X|^2] \big)^{\tfrac{1}{2}} $
# #### $ \text{Show that } |X| \text{ is the norm on } L^{2}(\Omega{}) $.

# %% [markdown]
# #### **(3)** $ \text{For } X, Y \in{} L^{2}(\Omega{}), \text{define } \langle{} X, Y \rangle{} := \mathbb{E}[XY] $
# #### $ \text{Show that } \langle{} X, Y \rangle{} $ is the inner product on $ L^2(\Omega{}) $.
