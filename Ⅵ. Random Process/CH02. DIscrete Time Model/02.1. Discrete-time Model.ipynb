# %% [markdown]
# # CH02.1. **Discrete-time Random Process**

# %% [markdown]
# > ## **(White Noise)**

# %% [markdown]
# #### **(1) 정의** : 이산 시간 확률 과정 $ \{ W[n] \} $가 평균이 상수이고, 자기공분산이 크로네커 델타 형태인 과정
# #### $ = $ 서로 다른 시점끼리는 상관이 없고(uncorrelated), 모든 시점에서 분산이 동일한 “잡음” 과정
# #### $ \Rrightarrow{} $ **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(Simple Random Walk)**

# %% [markdown]
# #### **(1) 정의** : **[~]**
# #### $ = $ **[~]**
# #### $ \Rrightarrow{} $ **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **자기회귀 과정(Auto Regression Process;AR Process)**

# %% [markdown]
# #### **(1) 정의** : **[~]**
# #### $ = $ **[~]**
# #### $ \Rrightarrow{} $ **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(ARMA)**

# %% [markdown]
# #### **(1) 정의** : **[~]**
# #### $ = $ **[~]**
# #### $ \Rrightarrow{} $ **[~]**
