# %% [markdown]
# # CH03.4. **Continous-time Random Process**

# %% [markdown]
# > ## **(Poisson process)**

# %% [markdown]
# #### **(1) 정의** : **[~]**
# #### $ = $ **[~]**
# #### $ \Rrightarrow{} $ **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(Compound Poisson Process)**

# %% [markdown]
# #### **(1) 정의** : **[~]**
# #### $ = $ **[~]**
# #### $ \Rrightarrow{} $ **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(Renewal Poisson Process)**

# %% [markdown]
# #### **(1) 정의** : **[~]**
# #### $ = $ **[~]**
# #### $ \Rrightarrow{} $ **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **브라운 모션(Brownian Motion;Wiener Process)**

# %% [markdown]
# #### **(1) 정의** : **[~]**
# #### $ = $ **[~]**
# #### $ \Rrightarrow{} $ **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(Continuous-time finite-state Markov chain)**

# %% [markdown]
# #### **(1) 정의** : **[~]**
# #### $ = $ **[~]**
# #### $ \Rrightarrow{} $ **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **(Ornstein–Uhlenbeck Process;OU Process)**

# %% [markdown]
# #### **(1) 정의** : **[~]**
# #### $ = $ **[~]**
# #### $ \Rrightarrow{} $ **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# <b></b>
