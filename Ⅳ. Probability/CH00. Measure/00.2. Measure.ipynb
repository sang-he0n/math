# %% [markdown]
# # CH00.2. **Measure**

# %% [markdown]
# > ## **측도(Measure)**

# %% [markdown]
# #### **(1) 정의** : 어떠한 가측 공간에서 시그마-대수의 원소를 사용하여 확장 비음수 실수값을 반환하는 집합 함수(set function)
# #### $ = $ 집합의 크기를 산정하는 함수
# #### $ \Rrightarrow{} \mu{} : \mathcal{F} \rightarrow{} [0, \infty{} ] $

# %% [markdown]
# #### **(2) 공리** : 어떠한 시그마-대수 $ \mathcal{F} $에 대응되는 측도 $ \mu{} $가 존재할 때 아래를 만족해야함
# ##### $ \hspace{0.15cm} $ ① $ \mu{}(A) \geq{} 0 \; (\forall{} \, A \in{} \mathcal{F}) $
# ##### $ \hspace{0.15cm} $ ② $ \mu{}(\empty{}) = 0 $
# ##### $ \hspace{0.15cm} $ ③ $ \displaystyle{} A_{i} \cap{} A_{j} = \empty{} \;\; (\forall{} \, i \neq{} j) \; \Rightarrow{} \; \mu{}(\bigcup^{\infty{}}_{i=1}A_{i}) = \sum^{\infty{}}_{i=1} \mu{}(A_{i}) \;\; \text{ where } \, A_{i} \in{} \mathcal{F} $

# %% [markdown]
# #### **(3) 성질** : 어떠한 집합 $ U $와 측도 $ \mu{} $가 존재할 때 아래를 만족함
# ##### $ \hspace{0.15cm} $ ① $ A \subseteq{} B \; \Rightarrow{} \; \mu{}(A)\le{} \mu{}(B) \;\; \text{ where } \, A, B \in{} \mathcal{F} $
# ##### $ \hspace{0.15cm} $ ② $ \displaystyle{} \mu{}\left({} \bigcup_{i=1}^\infty{} A_{i}\right) \le{} \sum_{i=1}^\infty{} \mu{}(A_{i}) $

# %% [markdown]
# #### **(4) 종류** :
# ##### $ \hspace{0.15cm} $ ① 계수 측도(Counting measure)
# ##### $ \hspace{0.45cm} \Rrightarrow{} \mu{}(A) = \begin{cases} |A| & \text{if } \, A \, \text{ is finite} \\ \infty{} & \text{if } \, A \, \text{ is infinite} \end{cases} $
# ##### $ \hspace{0.15cm} $ ② 보렐 측도(Borel measure) : **[~]**
# ##### $ \hspace{0.45cm} \Rrightarrow{} $ **[~]**
# ##### $ \hspace{0.15cm} $ ③ 확률 측도(Probability measure)
# ##### $ \hspace{0.45cm} \Rrightarrow{} \mathbb{P}(\Omega{}) = 1 $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **측도 공간(Measure space)**

# %% [markdown]
# #### **(1) 정의** : 어떠한 집합과 그 집합과 대응되는 시그마-대수, 측도와 함께 구성된 객체
# #### $ \Rrightarrow{} (U, \mathcal{F}, \mu{}) $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## (Theorem 0-n) **Basic Properties of Measure**

# %% [markdown]
# #### **(1)** 포함관계에 따라 측도도 증가한다. (단조성;Monotonicity)
# #### $ \Rrightarrow{} A \subseteq{} B,\;\; A,B \in{}\mathcal{F} \; \Rightarrow{} \; \mu{}(A)\le{}\mu{}(B) $

# %% [markdown]
# #### **(2)** 서로소인 유한 개의 가측집합의 합집합에 대한 측도는 각 측도의 합과 같다. (유한가법성;Finite Additivity)
# #### $ \Rrightarrow{} A \cap{} B = \empty{} \; \Rightarrow{} \;\mu{}(A \cup{} B)=\mu{}(A)+\mu{}(B) $

# %% [markdown]
# #### **(3)** 가측집합들의 합집합에 대한 측도는 각 측도의 합보다 크지 않다. (부분가법성;Subadditivity)
# #### $ \Rrightarrow{} \mu{}\left(\bigcup_{i=1}^{\infty{}} A_{i}\right)\le{}\sum_{i=1}^{\infty{}}\mu{}(A_{i}) \;\; \text{ where } \, A_{i}\in{}\mathcal{F} $

# %% [markdown]
# #### **(4)** 포함관계에 있는 두 가측집합의 차집합 측도를 뺄셈으로 표현할 수 있다.
# #### $ \Rrightarrow{} A \subseteq{} B,\;\; A,B \in{}\mathcal{F},\;\; \mu{}(A)<\infty{} \;\; \Rightarrow{} \;\; \mu{}(B\setminus{}A)=\mu{}(B)-\mu{}(A) $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **영측도 집합(Null Set)**

# %% [markdown]
# #### **(1) 정의** :

# %% [markdown]
# ##### **(`PLUS`) 영측도 집합(measure-zero set)** : 측도가 $ 0 $인 집합
# ##### $ \hspace{0.15cm} \Rrightarrow{} \mu{}(A) = 0 $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **측도 공간의 완비성(Completeness of Measure space)**

# %% [markdown]
# #### **(1) 정의** : 측도 공간 $ (U,\mathcal{F},\mu{}) $에서 모든 영측도 집합의 부분집합까지 시그마-대수 $ \mathcal{F} $가 포함하는 성질
# #### $ \Rrightarrow $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **측도 공간의 완비화(Completion of Measure space)**

# %% [markdown]
# #### **(1) 정의** :
# #### $ \Rrightarrow $

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## (Theorem 0-n) **Continuity of Measure**

# %% [markdown]
# #### **(1)** 어떠한 집합열 $ A_{1}\subseteq{}A_{2}\subseteq{}\cdots{} $이 존재할 때 그 합집합의 측도는 각 집합의 측도의 극한과 같다.
# #### $ \Rrightarrow{} \displaystyle{} \mu{}\Big({}\bigcup_{n=1}^{\infty{}}A_{n}\Big) = \lim_{n\to{}\infty{}}\mu{}(A_{n}) \;\; \text{ s.t. } \, A_{1}\subseteq{}A_{2}\subseteq{}\cdots{}, \;\; A_{n}\in{}\mathcal{F} $

# %% [markdown]
# #### **(2)** 어떠한 집합열 $ A_{1}\supseteq{}A_{2}\supseteq{}\cdots{} $이 존재하고 $ \mu{}(A_{1})<\infty{} $일 때 그 교집합의 측도는 각 집합의 측도의 극한과 같다.
# #### $ \Rrightarrow{} \displaystyle{} \mu{}\Big({}\bigcap_{n=1}^{\infty{}}A_{n}\Big) = \lim_{n\to{}\infty{}}\mu{}(A_{n}) \;\; \text{ s.t. } \, A_{1}\supseteq{}A_{2}\supseteq{}\cdots{}, \;\; A_{n}\in{}\mathcal{F}, \;\; \mu{}(A_{1})<\infty{} $

# %% [markdown]
# <b></b>
