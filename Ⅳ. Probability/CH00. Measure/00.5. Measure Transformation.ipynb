# %% [markdown]
# # CH00.5. **Measure Transformation**

# %% [markdown]
# 1. Restriction Measure
#
# 2. Image Measure
#
# 3. Pushforward Measure
#
# 4. Product Measure
#
# 5. Marginal Measure
#
# 6. Absolute Continuity
#
# 7. Singularity
#
# 8. Radon-Nikodym Derivative
