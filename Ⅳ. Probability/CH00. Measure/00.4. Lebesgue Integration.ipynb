# %% [markdown]
# # CH00.4. **Lebesgue Integration**

# %% [markdown]
# > ## **르베그 적분(Lebesgue Integral)**

# %% [markdown]
# #### **(1) 정의** : **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **단순 함수 적분(Integration of Simple Function)**

# %% [markdown]
# #### **(1) 정의** : **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **비음수 가측함수의 적분(_)**

# %% [markdown]
# #### **(1) 정의** : **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## **일반 실수가측함수의 적분(_)**

# %% [markdown]
# #### **(1) 정의** : **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## (Theorem 0-n) **Basic Properties of Lebesgue Integral**

# %% [markdown]
# #### **[~]**

# %% [markdown]
# <b></b>

# %% [markdown]
# > ## (Theorem 0-n) **Convergence Theorems**

# %% [markdown]
# #### **[~]**
