# %% [markdown]
# # CH00.6. **Lebesgue Integration**

# %% [markdown]
# 1. Lebesgue Integral
#
# 2. Construction of Lebesgue Integral
#
#     2.1 Integral of Indicator Function
#
#     2.2 Integral of Simple Function
#
#     2.3 Integral of Nonnegative Measurable Function
#
#     2.4 Integral of General Measurable Function
#
# 3. Integrability
#
#     3.1 Integrable Function
#
#     3.2 Positive Part and Negative Part
#
#     3.3 Absolute Integrability
#
# 4. Basic Properties of Lebesgue Integral
#
#     4.1 Linearity
#
#     4.2 Monotonicity
#
#     4.3 Triangle Inequality
#
# 5. Change of Variables by Pushforward
#
# 6. Limit Theorems
#
#     6.1 Monotone Convergence Theorem
#
#     6.2 Fatou Lemma
#
#     6.3 Dominated Convergence Theorem
#
# 7. Product Integration
#
#     7.1 Tonelli Theorem
#
#     7.2 Fubini Theorem
